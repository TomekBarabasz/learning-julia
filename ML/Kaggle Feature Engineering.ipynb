# %%
using ScikitLearn, InformationMeasures, RDatasets

# %%
@sk_import feature_selection: mutual_info_regression
# Out:
# PyObject <function mutual_info_regression at 0x7f0dfe9d9e50>

# %%
using DataFrames, CSV, MultivariateStats

# %%
using MLJ

# %%
using Plots, StatsPlots
# Out:
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1278

# %%
#using LinearAlgebra: svd
using LinearAlgebra

# %%
autos = CSV.read("./Data/autos.csv",DataFrame);

# %%
describe(autos)
# Out:
# 25×7 DataFrame
#  Row │ variable           mean      min          median   max    nmissing  elt ⋯
#      │ Symbol             Union…    Any          Union…   Any    Int64     Dat ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ symboling          0.797927  -2           1.0      3             0  Int ⋯
#    2 │ make                         alfa-romero           volvo         0  Str
#    3 │ fuel_type                    diesel                gas           0  Str
#    4 │ aspiration                   std                   turbo         0  Str
#    5 │ num_of_doors       3.16062   2            4.0      4             0  Int ⋯
#    6 │ body_style                   convertible           wagon         0  Str
#    7 │ drive_wheels                 4wd                   rwd           0  Str
#    8 │ engine_location              front                 rear          0  Str
#    9 │ wheel_base         98.9238   86.6         97.0     120.9         0  Flo ⋯
#   10 │ length             174.326   141.1        173.2    208.1         0  Flo
#   11 │ width              65.8938   60.3         65.4     72.0          0  Flo
#   ⋮  │         ⋮             ⋮           ⋮          ⋮       ⋮       ⋮          ⋱
#   16 │ engine_size        128.124   61           120.0    326           0  Int
#   17 │ fuel_system                  1bbl                  spfi          0  Str ⋯
#   18 │ bore               3.33062   2.54         3.31     3.94          0  Flo
#   19 │ stroke             3.24886   2.07         3.29     4.17          0  Flo
#   20 │ compression_ratio  9.8601    7            9.0      23            0  Int
#   21 │ horsepower         103.482   48           95.0     262           0  Int ⋯
#   22 │ peak_rpm           5099.74   4150         5100.0   6600          0  Int
#   23 │ city_mpg           25.3264   13           25.0     49            0  Int
#   24 │ highway_mpg        30.7876   16           30.0     54            0  Int
#   25 │ price              13285.0   5118         10245.0  45400         0  Int ⋯
#                                                      1 column and 4 rows omitted

# %%
CatColumnNames = names(autos[!,[eltype(c)==String for c in eachcol(autos)]])
# Out:
# 8-element Array{String,1}:
#  "make"
#  "fuel_type"
#  "aspiration"
#  "body_style"
#  "drive_wheels"
#  "engine_location"
#  "engine_type"
#  "fuel_system"

# %%
for name in CatColumnNames
    println(name, " : ", unique(autos[!,name]))
end
# Out:
# make : ["alfa-romero", "audi", "bmw", "chevrolet", "dodge", "honda", "isuzu", "jaguar", "mazda", "mercedes-benz", "mercury", "mitsubishi", "nissan", "peugot", "plymouth", "porsche", "saab", "subaru", "toyota", "volkswagen", "volvo"]
# fuel_type : ["gas", "diesel"]
# aspiration : ["std", "turbo"]
# body_style : ["convertible", "hatchback", "sedan", "wagon", "hardtop"]
# drive_wheels : ["rwd", "fwd", "4wd"]
# engine_location : ["front", "rear"]
# engine_type : ["dohc", "ohcv", "ohc", "l", "ohcf"]
# fuel_system : ["mpfi", "2bbl", "mfi", "1bbl", "spfi", "idi", "spdi"]

# %%
features = [:GarageArea, :YearRemodAdd, :TotalBsmtSF, :GrLivArea ]
# Out:
# 4-element Array{Symbol,1}:
#  :GarageArea
#  :YearRemodAdd
#  :TotalBsmtSF
#  :GrLivArea

# %%
using Statistics

# %%
ames = CSV.read("./Data/ames.csv",DataFrame);

# %%
describe(ames)
# Out:
# 79×7 DataFrame
#  Row │ variable          mean       min                         median    max  ⋯
#      │ Symbol            Union…     Any                         Union…    Any  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ MSSubClass                   Duplex_All_Styles_and_Ages            Two_ ⋯
#    2 │ MSZoning                     A_agr                                 Resi
#    3 │ LotFrontage       57.6478    0.0                         63.0      313.
#    4 │ LotArea           10147.9    1300.0                      9436.5    2152
#    5 │ Street                       Grvl                                  Pave ⋯
#    6 │ Alley                        Gravel                                Pave
#    7 │ LotShape                     Irregular                             Slig
#    8 │ LandContour                  Bnk                                   Lvl
#    9 │ Utilities                    AllPub                                NoSe ⋯
#   10 │ LotConfig                    Corner                                Insi
#   11 │ LandSlope                    Gtl                                   Sev
#   ⋮  │        ⋮              ⋮                  ⋮                  ⋮           ⋱
#   70 │ PoolArea          2.24334    0.0                         0.0       800.
#   71 │ PoolQC                       Excellent                             Typi ⋯
#   72 │ Fence                        Good_Privacy                          No_F
#   73 │ MiscFeature                  Elev                                  TenC
#   74 │ MiscVal           50.6352    0.0                         0.0       1700
#   75 │ MoSold            6.21604    1                           6.0       12   ⋯
#   76 │ YearSold          2007.79    2006                        2008.0    2010
#   77 │ SaleType                     COD                                   WD
#   78 │ SaleCondition                Abnorml                               Part
#   79 │ SalePrice         1.80796e5  12789                       160000.0  7550 ⋯
#                                                    3 columns and 58 rows omitted

# %%
c=cor(convert(Array,ames[!,features]),convert(Vector,ames[!,:SalePrice]))
# Out:
# 4×1 Array{Float64,2}:
#  0.640138298487373
#  0.532973754026695
#  0.6325288490320323
#  0.7067799209766275

# %%
DataFrame(names=features, correlation=c[:,1])
# Out:
# 4×2 DataFrame
#  Row │ names         correlation
#      │ Symbol        Float64
# ─────┼───────────────────────────
#    1 │ GarageArea       0.640138
#    2 │ YearRemodAdd     0.532974
#    3 │ TotalBsmtSF      0.632529
#    4 │ GrLivArea        0.70678

# %%
ames_subset = ames[:,features];

# %%
#nie działa
#combine(ames_subset, features => (x) -> cor(x, ames[!,:SalePrice]))

# %%
M=fit(PCA,convert(Array,ames_subset)', method=:svd)
# Out:
# PCA(indim = 4, outdim = 3, principalratio = 0.9992766204058094)

# %%
mean(M)
# Out:
# 4-element Array{Float64,1}:
#   472.65836177474404
#  1984.266552901024
#  1051.2556313993175
#  1499.6904436860068

# %%
                  PC1       PC2       PC3       PC4
GarageArea    0.541229  0.102375 -0.038470  0.833733
YearRemodAdd  0.427077 -0.886612 -0.049062 -0.170639
TotalBsmtSF   0.510076  0.360778 -0.666836 -0.406192
GrLivArea     0.514294  0.270700  0.742592 -0.332837
# Out:
# syntax: extra token "PC2" after end of expression
#
# Stacktrace:
#  [1] top-level scope at In[19]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
projection(M)
# Out:
# 4×3 Array{Float64,2}:
#  -0.227363   -0.0586085    0.971734
#  -0.0133136  -0.00195081   0.0220368
#  -0.583169   -0.791151    -0.184298
#  -0.779771    0.608803    -0.14588

# %%
principalvars(M)
# Out:
# 3-element Array{Float64,1}:
#  345033.03254762484
#  121480.08247913633
#   29690.856597438273

# %%
principalratio(M)
# Out:
# 0.9992766204058094

# %%
first(ames_subset,5)
# Out:
# 5×4 DataFrame
#  Row │ GarageArea  YearRemodAdd  TotalBsmtSF  GrLivArea
#      │ Float64     Int64         Float64      Float64
# ─────┼──────────────────────────────────────────────────
#    1 │      528.0          1960       1080.0     1656.0
#    2 │      730.0          1961        882.0      896.0
#    3 │      312.0          1958       1329.0     1329.0
#    4 │      522.0          1968       2110.0     2110.0
#    5 │      482.0          1998        928.0     1629.0

# %%
ames_subset_scaled = mapcols(x->(x.-mean(x))./std(x), ames_subset);
first(ames_subset_scaled,5)
# Out:
# 5×4 DataFrame
#  Row │ GarageArea  YearRemodAdd  TotalBsmtSF  GrLivArea
#      │ Float64     Float64       Float64      Float64
# ─────┼──────────────────────────────────────────────────
#    1 │  0.257179      -1.16329     0.0651847   0.309212
#    2 │  1.1959        -1.11535    -0.383827   -1.19422
#    3 │ -0.746598      -1.25917     0.629852   -0.337661
#    4 │  0.229296      -0.779786    2.40096     1.20732
#    5 │  0.0434117      0.658354   -0.279511    0.255801

# %%
c=cov(convert(Array,ames_subset_scaled))
# Out:
# 4×4 Array{Float64,2}:
#  1.0       0.375566  0.485608  0.483971
#  0.375566  1.0       0.298393  0.316855
#  0.485608  0.298393  1.0       0.445108
#  0.483971  0.316855  0.445108  1.0

# %%
vals,vecs = eigen(c)
# Out:
# Eigen{Float64,Float64,Array{Float64,2},Array{Float64,1}}
# values:
# 4-element Array{Float64,1}:
#  0.4933397395078824
#  0.5542944197462255
#  0.738471152242467
#  2.2138946885034256
# vectors:
# 4×4 Array{Float64,2}:
#   0.833733  -0.0384696   0.102375  -0.541229
#  -0.170639  -0.0490615  -0.886612  -0.427077
#  -0.406192  -0.666836    0.360778  -0.510076
#  -0.332837   0.742592    0.2707    -0.514294

# %%
U,S,V = svd(c)
# Out:
# SVD{Float64,Float64,Array{Float64,2}}
# U factor:
# 4×4 Array{Float64,2}:
#  -0.541229   0.102375  -0.0384696  -0.833733
#  -0.427077  -0.886612  -0.0490615   0.170639
#  -0.510076   0.360778  -0.666836    0.406192
#  -0.514294   0.2707     0.742592    0.332837
# singular values:
# 4-element Array{Float64,1}:
#  2.213894688503426
#  0.7384711522424672
#  0.5542944197462255
#  0.4933397395078828
# Vt factor:
# 4×4 Array{Float64,2}:
#  -0.541229   -0.427077   -0.510076  -0.514294
#   0.102375   -0.886612    0.360778   0.2707
#  -0.0384696  -0.0490615  -0.666836   0.742592
#  -0.833733    0.170639    0.406192   0.332837

# %%
cumsum(S)/sum(S)
# Out:
# 4-element Array{Float64,1}:
#  0.5534736721258563
#  0.738091460186473
#  0.8766650651230292
#  1.0

# %%
iris = dataset("datasets", "iris");
first(iris,5)
# Out:
# 5×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa

# %%
describe(iris)
# Out:
# 5×7 DataFrame
#  Row │ variable     mean     min     median  max        nmissing  eltype       ⋯
#      │ Symbol       Union…   Any     Union…  Any        Int64     DataType     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SepalLength  5.84333  4.3     5.8     7.9               0  Float64      ⋯
#    2 │ SepalWidth   3.05733  2.0     3.0     4.4               0  Float64
#    3 │ PetalLength  3.758    1.0     4.35    6.9               0  Float64
#    4 │ PetalWidth   1.19933  0.1     1.3     2.5               0  Float64
#    5 │ Species               setosa          virginica         0  CategoricalV ⋯
#                                                                 1 column omitted

# %%
iris_X = iris[!,Not(:Species)]
iris_y = iris[!,:Species];
unique(iris_y)
# Out:
# 3-element Array{String,1}:
#  "setosa"
#  "versicolor"
#  "virginica"

# %%
reshape( unique(iris_y), (1,3))
# Out:
# 1×3 Array{String,2}:
#  "setosa"  "versicolor"  "virginica"

# %%
labels = Dict( i => name for (i,name) in enumerate(unique(iris_y)) );

# %%
#setosa = iris[ iris.Species .== "setosa", [:SepalLength, :SepalWidth]];
species = [ (iris[ iris.Species .== name, :SepalLength], iris[ iris.Species .== name, :SepalWidth]) for name in unique(iris_y)]
scatter(species, label = reshape(unique(iris_y), (1,3)), alpha=0.7)

# %%
ms = mapcols(x -> (μ=mean(x),σ=std(x)), iris_X)
# Out:
# 1×4 DataFrame
#  Row │ SepalLength                  SepalWidth                   PetalLength   ⋯
#      │ NamedTuple…                  NamedTupl…                   NamedTuple…   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ (μ = 5.84333, σ = 0.828066)  (μ = 3.05733, σ = 0.435866)  (μ = 3.758, σ ⋯
#                                                                2 columns omitted

# %%
iris_scaled_X = DataFrame()
@time for cn in names(iris_X)
    col = iris_X[!,cn]
    μ,σ = mean(col), std(col)
    iris_scaled_X[:,cn] = (col .- μ) ./ σ
end
# Out:
#   0.000054 seconds (55 allocations: 12.391 KiB)

# %%
#cr=cor(convert(Array,iris_scaled_X)) correlation matrix is the same
c=cov(convert(Array,iris_scaled_X))
# Out:
# 4×4 Array{Float64,2}:
#   1.0       -0.11757    0.871754   0.817941
#  -0.11757    1.0       -0.42844   -0.366126
#   0.871754  -0.42844    1.0        0.962865
#   0.817941  -0.366126   0.962865   1.0

# %%
 U,S,V=svd(c)
# Out:
# SVD{Float64,Float64,Array{Float64,2}}
# U factor:
# 4×4 Array{Float64,2}:
#  -0.541229   0.102375  -0.0384696  -0.833733
#  -0.427077  -0.886612  -0.0490615   0.170639
#  -0.510076   0.360778  -0.666836    0.406192
#  -0.514294   0.2707     0.742592    0.332837
# singular values:
# 4-element Array{Float64,1}:
#  2.213894688503426
#  0.7384711522424672
#  0.5542944197462255
#  0.4933397395078828
# Vt factor:
# 4×4 Array{Float64,2}:
#  -0.541229   -0.427077   -0.510076  -0.514294
#   0.102375   -0.886612    0.360778   0.2707
#  -0.0384696  -0.0490615  -0.666836   0.742592
#  -0.833733    0.170639    0.406192   0.332837

# %%
vals,vecs = eigen(c)
# Out:
# Eigen{Float64,Float64,Array{Float64,2},Array{Float64,1}}
# values:
# 4-element Array{Float64,1}:
#  0.4933397395078824
#  0.5542944197462255
#  0.738471152242467
#  2.2138946885034256
# vectors:
# 4×4 Array{Float64,2}:
#   0.833733  -0.0384696   0.102375  -0.541229
#  -0.170639  -0.0490615  -0.886612  -0.427077
#  -0.406192  -0.666836    0.360778  -0.510076
#  -0.332837   0.742592    0.2707    -0.514294

# %%
sort( collect(zip(vals,eachcol(vecs))), rev=true )
# Out:
# 4-element Array{Tuple{Float64,SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true}},1}:
#  (2.2138946885034256, [-0.5412294221958748, -0.4270772547456739, -0.5100756026874698, -0.5142942840159054])
#  (0.738471152242467, [0.1023746696677728, -0.8866116458334643, 0.3607779840020004, 0.2706999496533799])
#  (0.5542944197462255, [-0.03846963237899531, -0.04906150720084851, -0.6668360722388553, 0.742591885665917])
#  (0.4933397395078824, [0.8337327071337426, -0.17063931687203732, -0.40619180021699486, -0.33283662362991595])

# %%
scree=cumsum(S)/sum(S)
# Out:
# 4-element Array{Float64,1}:
#  0.5534736721258563
#  0.738091460186473
#  0.8766650651230292
#  1.0

# %%
bar(["PC$x" for x in 1:4],scree;title="% of cumulative variance")

# %%
#y = rand(100, 4) # Four series of 100 points each
#violin(["Series 1" "Series 2" "Series 3" "Series 4"], y, leg = false)

#ir = convert(Array,iris_X)'
#violin(names(iris_X), ir)

#boxplot(names(iris_X), ir)

# %%
map( x->x[2], sort( collect(zip(vals,eachcol(vecs))), rev=true )[1:2] )
# Out:
# 2-element Array{SubArray{Float64,1,Array{Float64,2},Tuple{Base.Slice{Base.OneTo{Int64}},Int64},true},1}:
#  [-0.5412294221958748, -0.4270772547456739, -0.5100756026874698, -0.5142942840159054]
#  [0.1023746696677728, -0.8866116458334643, 0.3607779840020004, 0.2706999496533799]

# %%
v1 = [-0.897674 1.0156 -1.33575 -1.31105]
v2 = [-0.33283662362991595 0.742591885665917 0.2706999496533799 -0.5142942840159054]'
println("v1 ",size(v1))
println("v2 ",size(v2))
v1*v2
# Out:
# v1 (1, 4)
# v2 (4, 1)
# 1×1 Array{Float64,2}:
#  1.3656331656722172

# %%
#cols = [:SepalLength, :SepalWidth, :PetalLength, :PetalWidth]
#iris_scaled_X.PC1 = convert(Array,iris_scaled_X[!,cols])*vecs[:,4]
describe(iris_scaled_X)
#iris_scaled_X.PC2 = convert(Array,iris_scaled_X[!,cols])*vecs[:,3]
# Out:
# 6×7 DataFrame
#  Row │ variable     mean          min       median      max      nmissing  elt ⋯
#      │ Symbol       Float64       Float64   Float64     Float64  Int64     Dat ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.3033748319840264,
#             -0.9208933917746863,
#             -1.2652914449329375,
#             0.8286206326336806,
#             -0.623214433366759,
#             0.06350865712705787,
#             -1.0787771026640574,
#             1.5274780247858804,
#             -0.6516153472081794,
#             0.5941913350161008,
#             1.7962623979573138,
#             -0.3114392769422373,
#             0.80221585146937,
#             -0.42117831494482094,
#             0.2909370275217705,
#             -0.9226255705948111,
#             -0.20204107594221254,
#             0.4141248258547276,
#             0.18966340240062124,
#             0.7311307550585231,
#             -0.883188817349626,
#             -0.053461025636480586,
#             -0.28522623769254507,
#             -0.18825147860927915,
#             -0.4342102870256964,
#             -0.7592813693880788,
#             -0.8096139168665947,
#             -1.2004244640915083,
#             -0.36550013591798836,
#             0.7508365384804201,
#             0.9233695415017482,
#             1.0197357704208974,
#             0.3369707089624032,
#             -0.4103721930791442,
#             -0.07131977146921001,
#             -0.9228895244517963,
#             -1.076780969986947,
#             0.1901570737956944,
#             0.04848055236907271,
#             0.6326535346932196,
#             0.48656328845967073,
#             -0.49026727867855785,
#             0.4060596726961402,
#             1.5601009215196096,
#             0.3135366140432702,
#             0.021696958578732904,
#             0.05220886386630774,
#             -0.3034889825526933,
#             1.3179852833694718,
#             0.17908699807303186
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "versicolor",
#         "zmin": null,
#         "legendgroup": "versicolor",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(227, 111, 71, 0.700)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 0.700)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.11657950474298048,
#             0.03704028533451134,
#             0.3840183829356082,
#             1.5832816377680403,
#             0.8834953302997071,
#             0.6931255773960285,
#             -0.10234819452934737,
#             1.0560872070826846,
#             0.6214170525317448,
#             0.7476142374267527,
#             1.922979477736134,
#             0.32074045050639954,
#             1.7419692797605904,
#             0.6155526133520054,
#             0.29341376400953023,
#             0.22159219721455975,
#             0.34496281807925994,
#             0.7206119039796929,
#             2.046450869289011,
#             1.0973524552835803,
#             0.14307799943496619,
#             0.640391861610627,
#             1.530321838121265,
#             0.7479385904765631,
#             0.5353791691390478,
#             0.41264277307883596,
#             0.9259452402162743,
#             0.6541707832278572,
#             0.5978289097633729,
#             0.7890391257144442,
#             1.2679658054596024,
#             1.2120147288195051,
#             0.7507651545068706,
#             1.162793472901227,
#             0.32023661175132545,
#             -0.3837256344260012,
#             0.3184177252311652,
#             1.7639353658327956,
#             0.19218621342255726,
#             1.1764542797115531,
#             1.019275652484483,
#             0.3917017086355076,
#             0.9746160592233682,
#             1.2718639892748955,

# %% [markdown]
# ## Retrieve nth typle element - applied in list of tuples

# %%
t=[(0,:a), (1,:b), (2,:c)]
reshape([e[2] for e in t],1,3)
# Out:
# 1×3 Array{Symbol,2}:
#  :a  :b  :c

# %%
(x->x[2]).(t)
# Out:
# 3-element Array{Symbol,1}:
#  :a
#  :b
#  :c

# %%
map(x->x[2],t)
# Out:
# 3-element Array{Symbol,1}:
#  :a
#  :b
#  :c

# %%
[1:5;7:10]
# Out:
# 9-element Array{Int64,1}:
#   1
#   2
#   3
#   4
#   5
#   7
#   8
#   9
#  10

# %%
IrisPCA=fit(PCA,convert(Array,iris_X)', method=:svd)
# Out:
# PCA(indim = 4, outdim = 3, principalratio = 0.9947878161267246)
